# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import requests
from bs4 import BeautifulSoup

# %%
driver = webdriver.Chrome()

# %%
driver.get("https://www.zaubacorp.com/company-list")

# %%
html_content = driver.page_source

# %%
soup = BeautifulSoup(html_content, 'html.parser')

# %%
soup.prettify()
# Out:
# '<html class="js js flexbox flexboxlegacy canvas canvastext webgl no-touch geolocation postmessage no-websqldatabase indexeddb hashchange history draganddrop websockets rgba hsla multiplebgs backgroundsize borderimage borderradius boxshadow textshadow opacity cssanimations csscolumns cssgradients cssreflections csstransforms csstransforms3d csstransitions fontface generatedcontent video audio localstorage sessionstorage webworkers no-applicationcache svg inlinesvg smil svgclippaths" dir="ltr" lang="en" style="">\n <head profile="http://www.w3.org/1999/xhtml/vocab">\n  <meta content="" http-equiv="origin-trial"/>\n  <meta charset="utf-8"/>\n  <meta content="width=device-width, initial-scale=1.0" name="view
# ...

# %%
tables = soup.find('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')

# %%
tables
# Out:
# <table class="table table-striped col-md-12 col-sm-12 col-xs-12" id="table">
# <thead>
# <tr>
# <th class="tab-tc-1"> <h5><b>CIN</b></h5></th>
# <th class="tab-tc-2"> <h5><b>Company</b></h5></th>
# <th class="tab-tc-2"> <h5><b>RoC</b></h5></th>
# <th class="tab-tc-2"> <h5><b>Status</b></h5></th>
# </tr>
# </thead>
# <tbody><tr>
# <td>AAE-6126</td>
# <td><a href="https://www.zaubacorp.com/company/PACIFIC-INFRABUILD-LLP/AAE-6126">PACIFIC INFRABUILD LLP</a></td>
# <td>Delhi</td>
# <td>Active</td>
# </tr>
# <tr>
# <td>AAF-1027</td>
# <td><a href="https://www.zaubacorp.com/company/AFFAIRS-EVENT-MANAGEMENT-LLP/AAF-1027">AFFAIRS EVENT MANAGEMENT LLP</a></td>
# <td>Gwalior</td>
# <td>Active</td>
# </tr>
# <tr>
# <td>AAF-8155</td>
# <td><a href="https://www.zaubacorp.com/company/VIPANI-ONLINE-SHOPPING-PORTAL-LLP/AAF-8155">VIPANI ONLINE SHOPPING PORTAL LLP</a></td>
# <td>Ernakulam</td>
# <td>Active</td>
# </tr>
# <tr>
# <td>AAF-9145</td>
# ...

# %%
import pandas as pd

# %%
pd.read_html(str(tables))
# Out:
# C:\Users\shubh\AppData\Local\Temp\ipykernel_9440\2126409953.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(str(tables))
# [                      CIN                                            Company  \
#  0                AAE-6126                             PACIFIC INFRABUILD LLP
#  1                AAF-1027                       AFFAIRS EVENT MANAGEMENT LLP
#  2                AAF-8155                  VIPANI ONLINE SHOPPING PORTAL LLP
#  3                AAF-9145                               ARMADILLO REALTY LLP
#  4                AAG-0314                       AJAY AGGARWAL PROPERTIES LLP
#  5                AAG-4170                     BEFREE BUSINESS RESOURCING LLP
#  6                AAG-4211                          SIS MERCHANTILE INDIA LLP
#  7                AAG-4332                                VIRAT PROMOTERS LLP
# ...

# %%
for i in range(1,13334):
    url = f"https://www.zaubacorp.com/company-list/p-{i}-company.html"
    print(url)
# Out:
# https://www.zaubacorp.com/company-list/p-1-company.html
# https://www.zaubacorp.com/company-list/p-2-company.html
# https://www.zaubacorp.com/company-list/p-3-company.html
# https://www.zaubacorp.com/company-list/p-4-company.html
# https://www.zaubacorp.com/company-list/p-5-company.html
# https://www.zaubacorp.com/company-list/p-6-company.html
# https://www.zaubacorp.com/company-list/p-7-company.html
# https://www.zaubacorp.com/company-list/p-8-company.html
# https://www.zaubacorp.com/company-list/p-9-company.html
# https://www.zaubacorp.com/company-list/p-10-company.html
# https://www.zaubacorp.com/company-list/p-11-company.html
# https://www.zaubacorp.com/company-list/p-12-company.html
# https://www.zaubacorp.com/company-list/p-13-company.html
# https://www.zaubacorp.com/company-list/p-14-company.html
# https://www.zaubacorp.com/company-list/p-15-company.html
# https://www.zaubacorp.com/company-list/p-16-company.html
# https://www.zaubacorp.com/company-list/p-17-company.html
# ...

# %%
name = soup.find_all('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')

# %%
for i in name[1:]:
    row = i.text()
    print(row)

# %%
len(name)
# Out:
# 1

# %%
headers = tables.find_all('th')
#print(headers)

# %%
titles = []
for i in headers:
    title = i.text
    titles.append(title)

# %%
titles
# Out:
# [' CIN', ' Company', ' RoC', ' Status']

# %%
df = pd.DataFrame(columns=[titles])

# %%
df
# Out:
# Empty DataFrame
# Columns: [( CIN,), ( Company,), ( RoC,), ( Status,)]
# Index: []

# %%
df.columns
# Out:
# MultiIndex([(    ' CIN',),
#             (' Company',),
#             (    ' RoC',),
#             ( ' Status',)],
#            )

# %%
rows = tables.find_all('tr')
#rows

# %%
#for i in rows[1:]:
    #print(i.text)

# %%
for i in rows[1:]:
    data  = i.find_all('td')
    rows = [tr.text for tr in data]
    #print(rows)
    l = len(df)
    df.loc[l] = rows

# %%
df
# Out:
#                       CIN                                            Company  \
# 0   U72900MH2011PTC219787               GEETA TECHNO SYSTEMS PRIVATE LIMITED
# 1   U45400BR2022PTC056579                  SAMTVA INDUSTRIES PRIVATE LIMITED
# 2   U45200BR2010PTC016020                    ARPAN BUILDTECH PRIVATE LIMITED
# 3   U74900WB2016PTC209898                    GRENZ MOTOCRAFT PRIVATE LIMITED
# 4   U40200MP2021PTC058170                   SHIVATHMIKA URJA PRIVATE LIMITED
# 5   U72900WB2012PTC173813                        BOSON ITECH PRIVATE LIMITED
# 6   U72200KA1995PTC019080                  HIREMATH SYSTRAIN PRIVATE LIMITED
# 7   U51109WB1951PTC019686                               DATTAS INDIA PVT LTD
# 8   U80302RJ2014PTC044857                 VARDHAN EDUCATIONS PRIVATE LIMITED
# 9   U51909MH2004PTC145684             NRC CLASSIC TRADE LINK PRIVATE LIMITED
# 10  U74999DL2018PTC332871                       HEET TRADING PRIVATE LIMITED
# ...

# %% [markdown]
# # Scrapping for 13333 Pages

# %%
for i in range(1,501):
    url = f"https://www.zaubacorp.com/company-list/p-{i}-company.html"
    driver.get(url)
    html_content = driver.page_source
    soup = BeautifulSoup(html_content, 'html.parser')
    tables = soup.find('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')
    
    #headers = tables.find_all('th')
    #titles = []
    #for i in headers:
        #title = i.text
        #titles.append(title)
        
    #df = pd.DataFrame(columns=[titles])
    
    rows = tables.find_all('tr')
    
    for i in rows[1:]:
        data  = i.find_all('td')
        rows = [tr.text for tr in data]
        #print(rows)
        l = len(df)
        df.loc[l] = rows

# %%
df
# Out:
#                          CIN                                 Company  \
# 0                   AAE-6126                  PACIFIC INFRABUILD LLP
# 1                   AAF-1027            AFFAIRS EVENT MANAGEMENT LLP
# 2                   AAF-8155       VIPANI ONLINE SHOPPING PORTAL LLP
# 3                   AAF-9145                    ARMADILLO REALTY LLP
# 4                   AAG-0314            AJAY AGGARWAL PROPERTIES LLP
# ...                      ...                                     ...
# 71545  U74999HR2016PTC065499       GMV ENTERTAINMENT PRIVATE LIMITED
# 71546  U65990TN2013PTC089396  SREEKUBERAN CHIT FUNDS PRIVATE LIMITED
# 71547  U74899DL1989PTC037629             PEACOCK STEEL TUBES PVT LTD
# 71548  U92490KL2023PTC079788               ALIENHUNK PRIVATE LIMITED
# 71549  U74999KA2020PTC140550         VUELOS HOLDINGS PRIVATE LIMITED
#
#              RoC                         Status
# 0          Delhi                         Active
# ...

# %%
for i in range(501,503):
    url = f"https://www.zaubacorp.com/company-list/p-{i}-company.html"
    driver.get(url)
    html_content = driver.page_source
    soup = BeautifulSoup(html_content, 'html.parser')
    tables = soup.find('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')
    
    #headers = tables.find_all('th')
    #titles = []
    #for i in headers:
        #title = i.text
        #titles.append(title)
        
    #df = pd.DataFrame(columns=[titles])
    
    rows = tables.find_all('tr')
    
    for i in rows[1:]:
        data  = i.find_all('td')
        rows = [tr.text for tr in data]
        #print(rows)
        l = len(df)
        df.loc[l] = rows

# %%
df
# Out:
#                          CIN  \
# 0                   AAE-6126
# 1                   AAF-1027
# 2                   AAF-8155
# 3                   AAF-9145
# 4                   AAG-0314
# ...                      ...
# 76825  U01110TG2020PTC146158
# 76826  U45201GJ2006PTC047510
# 76827  U74999MH2015PTC267059
# 76828  U74140KA2008PTC048414
# 76829  U99999DL2000PTC004273
#
#                                                  Company        RoC  \
# 0                                 PACIFIC INFRABUILD LLP      Delhi
# 1                           AFFAIRS EVENT MANAGEMENT LLP    Gwalior
# 2                      VIPANI ONLINE SHOPPING PORTAL LLP  Ernakulam
# 3                                   ARMADILLO REALTY LLP     Mumbai
# 4                           AJAY AGGARWAL PROPERTIES LLP      Delhi
# ...                                                  ...        ...
# 76825                GOPI RAM AGRO INDUS PRIVATE LIMITED  Hyderabad
# ...

# %%
for i in range(503,1004):
    url = f"https://www.zaubacorp.com/company-list/p-{i}-company.html"
    driver.get(url)
    html_content = driver.page_source
    soup = BeautifulSoup(html_content, 'html.parser')
    tables = soup.find('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')
    
    #headers = tables.find_all('th')
    #titles = []
    #for i in headers:
        #title = i.text
        #titles.append(title)
        
    #df = pd.DataFrame(columns=[titles])
    
    rows = tables.find_all('tr')
    
    for i in rows[1:]:
        data  = i.find_all('td')
        rows = [tr.text for tr in data]
        #print(rows)
        l = len(df)
        df.loc[l] = rows
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[42], line 16
#       6 tables = soup.find('table', 'table table-striped col-md-12 col-sm-12 col-xs-12')
#       8 #headers = tables.find_all('th')
#       9 #titles = []
#      10 #for i in headers:
#    (...)
#      13
#      14 #df = pd.DataFrame(columns=[titles])
# ---> 16 rows = tables.find_all('tr')
#      18 for i in rows[1:]:
#      19     data  = i.find_all('td')
#
# AttributeError: 'NoneType' object has no attribute 'find_all'

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 df[' Company'] = df[' Company'].pop()
#
# TypeError: DataFrame.pop() missing 1 required positional argument: 'item'

# %%
driver.get("https://www.zaubacorp.com/company/PACIFIC-INFRABUILD-LLP/AAE-6126")

# %%
html_content = driver.page_source
soup = BeautifulSoup(html_content, 'html.parser')

# %%
table = soup.find_all(['div','table'], ['col-lg-12 col-md-12 col-sm-12 col-xs-12', 'table table-striped'])

# %%
table
# Out:
# [<div class="col-lg-12 col-md-12 col-sm-12 col-xs-12" style="height: auto !important; min-height: 0px !important;">
#  <h4 class="company-data uppercase" style="border-bottom: solid 3px #428bca; padding-bottom: 3px">Company Details</h4>
#  <table class="table table-striped">
#  <thead>
#  <tr>
#  <td><p>LLP Identification Number</p></td>
#  <td><p><a href="https://www.zaubacorp.com/company/PACIFIC-INFRABUILD-LLP/AAE-6126">AAE-6126</a></p></td>
#  </tr>
#  </thead>
#  <tbody>
#  <tr>
#  <td>
#  <p>Company Name</p>
#  </td>
#  <td>
#  <p>PACIFIC INFRABUILD LLP</p>
#  </td>
#  </tr>
#  <tr>
#  <td>
#  <p>Company Status</p>
#  </td>
#  <td>
#  <p><span style="color:green">Active</span></p>
#  </td>
#  </tr>
#  <tr>
#  <td>
#  <p>RoC</p>
#  </td>
#  <td>
#  <p>RoC-Delhi</p>
#  </td>
#  </tr>
#  <tr>
#  <td>
#  <p>Main division of business activity to be carried out in India </p>
#  </td>
#  <td>
#  <p>Construction</p>
#  </td>
#  </tr>
#  <tr>
#  <td>
# ...

# %%
rows = table[6].find_all('tr')

# %%
rows
# Out:
# [<tr>
#  <td>
#  <p>Total Obligation of Contribution </p>
#  </td>
#  <td>
#  <p>₹5,500,000</p>
#  </td>
#  </tr>,
#  <tr>
#  <td>
#  <p>Number of Employees</p>
#  </td>
#  <td>
#  <p><a href="https://www.zaubacorp.com/user/login?destination=company/PACIFIC-INFRABUILD-LLP/AAE-6126">Login to view</a></p>
#  </td>
#  </tr>]

# %%
contact_details = soup.find_all('div', "col-12")

# %%
contact_details
# Out:
# [<div class="col-12">
#  <h4 class="company-data uppercase" style="border-bottom: solid 3px #428bca; padding-bottom: 3px">Contact Details</h4>
#  <div style="background: #fff; padding-bottom: 20px; margin-bottom: 20px">
#  <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12">
#  <p><b> Email ID: </b>jainvarun23@hotmail.com</p> <p><b>Website:</b> <span id="addwebsitespan&gt;"><a class="addwebsite_AAE-6126" data-target="#websiteModalconfirm" data-toggle="modal" href="#">Click here </a>  to add.</span></p>
#  <p><b>Address: </b></p><p>Farm No. 10, North Drive KH No. 733/2 DLF Chatarpur New Delhi South Delhi DL 110030 IN</p>
#  </div>
#  <div class="col-lg-6 col-md-6 col-sm-12 col-xs-12">
#  <iframe class="embed-responsive-item" frameborder="0" src="https://www.google.com/maps/embed/v1/place?q=Farm+No.+10%2C+North+Drive+KH+No.+733%2F2+DLF+Chatarpur+New+Delhi+South+Delhi+DL+110030+IN&amp;key=AIzaSyBpSAPhp_htOAtPWrGUjCzNyNcs-AhGr0Y" style="border:0;width: 100%; height:250px;"></iframe>
# ...

# %%
row = contact_details[0].find_all('p')

# %%
row
# Out:
# [<p><b> Email ID: </b>jainvarun23@hotmail.com</p>,
#  <p><b>Website:</b> <span id="addwebsitespan&gt;"><a class="addwebsite_AAE-6126" data-target="#websiteModalconfirm" data-toggle="modal" href="#">Click here </a>  to add.</span></p>,
#  <p><b>Address: </b></p>,
#  <p>Farm No. 10, North Drive KH No. 733/2 DLF Chatarpur New Delhi South Delhi DL 110030 IN</p>]

# %%
email = row[0].text.split(':')
email
# Out:
# [' Email ID', ' jainvarun23@hotmail.com']

# %%
import pandas as pd

# %%
df = pd.DataFrame(columns=[email[0]])

# %%
df.loc[len(df)] = email[1]

# %%
df
# Out:
#                    Email ID
# 0   jainvarun23@hotmail.com

# %%
website = row[1].text.split(':')
df['website'] = website[1]
df
# Out:
#                    Email ID                website
# 0   jainvarun23@hotmail.com   Click here   to add.

# %%
address = row[3].text
df['address'] = address
df
# Out:
#                    Email ID                website  \
# 0   jainvarun23@hotmail.com   Click here   to add.
#
#                                              address
# 0  Farm No. 10, North Drive KH No. 733/2 DLF Chat...
